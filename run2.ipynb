# %%
# %run llama_main.py --sparsity 0.1 --cudan "cuda:0"
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Starting...
# Ready.
# 0 self_attn.q_proj
# Pruning ...
# time 1.84
# error 0.037681788206100464
# 0 self_attn.k_proj
# Pruning ...
# time 0.98
# error 0.07203751802444458
# 0 self_attn.v_proj
# Pruning ...
# time 0.98
# error 0.1200217753648758
# 0 self_attn.o_proj
# Pruning ...
# time 0.98
# error 0.004720922559499741
# 0 mlp.up_proj
# Pruning ...
# time 1.10
# error 6.1702375411987305
# 0 mlp.gate_proj
# Pruning ...
# time 0.99
# error 6.291195869445801
# 0 mlp.down_proj
# Pruning ...
# time 2.82
# error 0.03381400555372238
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# File ~/sxy/sparseLLM repo/SparseLLM/llama_main.py:47
#      44         model.save_pretrained(args.save)
#      46 if __name__ == '__main__':
# ---> 47     main()
#
# File ~/sxy/sparseLLM repo/SparseLLM/llama_main.py:37, in main()
# ...

# %%
# %run opt_main.py --model 'facebook/opt-2.7b' --sparsity 0.1 --cudan "cuda:0"
# Out:
# config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.30G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/5.30G [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# Starting ...
# Ready.
# 0 self_attn.k_proj
# Pruning ...
# torch.Size([2048, 2560]) torch.Size([2560, 2560])
# Iter 2/100, Loss=0.152466
# Iter 10/100, Loss=0.152222
# Iter 20/100, Loss=0.151978
# Iter 30/100, Loss=0.151611
# Iter 40/100, Loss=0.151367
# Iter 50/100, Loss=0.151123
# Iter 60/100, Loss=0.150757
# Iter 70/100, Loss=0.150513
# Iter 80/100, Loss=0.150146
# Iter 90/100, Loss=0.149902
# Iter 100/100, Loss=0.149658
# Starting iterative correction ...
# ...
